# %%
import torch
import sys
import os
sys.path.append(os.path.abspath(os.path.join('..')))

# %%
def load_checkpoint(checkpoint_path):
    """Load a checkpoint and return the model state dict."""
    checkpoint = torch.load(checkpoint_path, map_location='cpu')
    print(checkpoint.keys())
    
    return checkpoint['0,1']

# %%
checkpoint_path = "/mnt/pengyanxin/my_megatron/examples/gpt3/gpt-345m-ckpts/iter_0000030/mp_rank_00/model_optim_rng.pt"

checkpoint = torch.load(checkpoint_path, map_location='cpu')

# %%
print(checkpoint['optimizer']['optimizer']['state'][0].keys())
# Out:
# dict_keys(['exp_avg', 'exp_avg_sq'])

# %%
print(checkpoint['optimizer']['optimizer'].keys())

# %%
print(checkpoint['optimizer']['optimizer']['state'])
